# %%
file_path_fasta = "/home/gbaylyyeva/shared_folder/file_format_examples/16s_database_top.fasta"

# %%
fasta_handle= open(file_path_fasta)
fasta_handle.read()
# Out:
# '>AY741702 Bacteria;Firmicutes;Clostridia;Clostridiales;Peptococcaceae 1700 bp          rna\\nGUG
# ...

# %%
stop_codons=["UAG","UAA","UGA"]
sequence= sequence.replace("\n","")
start_index= seq.index("AUG")


for i,nuct in enumerate (seq[start_index::3]):
    ind= start_index +1*3
    codon=seq[ind+3]
    if codon in stop_codons:
        stop_index=ind
        break
seq =[start_index:stop_index+3]           
print("start codon %s starts at index %d % (seq[start_index:start_index+3],start_index))
print("stop codon %s starts index %d" % (seq[stop_index:stop_index+3],stop_index))
print("sequence of the extracted coding region is as follows:")
print(seq[start_index:stop_index+3])
# Out:
#   File "<ipython-input-3-537e641c7a14>", line 12
#     seq =[start_index:stop_index+3]
#                      ^
# SyntaxError: invalid syntax

# %%
sequence = fasta_handle.read()

# %%
start_index=-1
stop_index=0

stop_codons=["UAG","UAA","UGA"]
sequence= sequence.replace("\n","")
for i, nucl in enumerate(sequence):
    ind=i*3
    codon= sequence[ind:ind+3]

    if codon =="AUG" and start_index == -1:
        start_index=ind
    
    elif codon == stop_codons[0] or codon == stop_codons[1] or codon == stop_codons[2]:
   
        stop_index = ind + 3
        if 0 <= start_index < stop_index:
            break
print(start_index,stop_index+3)
print(sequence[start_index:stop_index+3])


stop_index=0
stop_codons=["UAG","UAA","UGA"]
sequence= sequence.replace("\n","")

 start_index = sequence.index ("AUG")
for i, nucl in enumerate(sequence[start_index+3::3]):
    ind=i*3
    codon= sequence[ind:ind+3]

    if codon in stop_codons:
        start_index=ind+3
        if start_index < stop_index:
            break
            
print(start_index,stop_index)
print(sequence[start_index:stop_index])
# Out:
#   File "<ipython-input-5-74a9d25d0d75>", line 26
#     start_index = sequence.index ("AUG")
#     ^
# IndentationError: unexpected indent
